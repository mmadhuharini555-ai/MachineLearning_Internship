# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
athe=pd.read_csv('/content/drive/MyDrive/INTERNSHIP/Madhu/Linear&Logistic/athlete_performance_data.csv')

# %%
athe.head()
# Out:
#   Athlete_ID Athlete_Name Sport_Type          Event  Training_Hours_per_Week  \
# 0       A754   Athlete_15    Running  50m Freestyle                    18.11
# 1       A792   Athlete_95     Soccer            NaN                    12.43
# 2       A195   Athlete_28   Swimming    100m Sprint                    11.99
# 3       A559   Athlete_76    Cycling    100m Sprint                    20.41
# 4       A384   Athlete_20   Swimming  50m Freestyle                    37.88
#
#    Average_Heart_Rate   BMI  Sleep_Hours_per_Night  Daily_Caloric_Intake  \
# 0               192.6  29.6                    7.6                1890.0
# 1                77.3  18.7                    NaN                2811.9
# 2               127.1  26.8                    NaN                3018.9
# 3                68.3  24.9                    4.2                3773.3
# 4               184.2  27.0                    9.5                1721.2
#
# ...

# %%
athe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12600 entries, 0 to 12599
# Data columns (total 21 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Athlete_ID                        11967 non-null  object
#  1   Athlete_Name                      11971 non-null  object
#  2   Sport_Type                        11971 non-null  object
#  3   Event                             11962 non-null  object
#  4   Training_Hours_per_Week           11970 non-null  float64
#  5   Average_Heart_Rate                11970 non-null  float64
#  6   BMI                               11971 non-null  float64
#  7   Sleep_Hours_per_Night             11976 non-null  float64
#  8   Daily_Caloric_Intake              11958 non-null  float64
#  9   Hydration_Level                   11963 non-null  float64
#  10  Injury_History                    7884 non-null   object
# ...

# %%
athe.isnull().sum()
# Out:
# Athlete_ID                           633
# Athlete_Name                         629
# Sport_Type                           629
# Event                                638
# Training_Hours_per_Week              630
# Average_Heart_Rate                   630
# BMI                                  629
# Sleep_Hours_per_Night                624
# Daily_Caloric_Intake                 642
# Hydration_Level                      637
# Injury_History                      4716
# Previous_Competition_Performance     630
# Training_Intensity                   645
# Resting_Heart_Rate                   631
# Body_Fat_Percentage                  632
# VO2_Max                              633
# Event_Distance                       635
# Altitude_Training                   3628
# Mental_Focus_Level                   628
# Competition_Date                     627
# Performance_Metric                   618
# dtype: int64

# %%
inp=athe[['Training_Hours_per_Week']]
out=athe['Performance_Metric']

# %%
LR=LinearRegression()

# %%
train_data=pd.concat([inp,out],axis=1)
train=train_data.dropna()

# %%
inp1=train[['Training_Hours_per_Week']]
out1=train['Performance_Metric']

# %%
LR.fit(inp1,out1)
# Out:
# LinearRegression()

# %%
LR.predict([[5]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([50.42624218])
